# %%
import yfinance as yf
import pandas as pd
# import talib
import matplotlib.pyplot as plt
import datetime

# %%
stock = yf.Ticker("^GSPC")
data = yf.download("^GSPC", start="2000-01-01", end="2022-12-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  1455.219971
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1399.420044
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1402.109985
# 2000-01-06  1402.109985  1411.900024  1392.099976  1403.449951  1403.449951
# 2000-01-07  1403.449951  1441.469971  1400.729980  1441.469971  1441.469971
#
#                 Volume
# Date
# 2000-01-03   931800000
# 2000-01-04  1009000000
# 2000-01-05  1085500000
# 2000-01-06  1092300000
# 2000-01-07  1225200000

# %%
stock = ["BTC-USD", "QQQ", "XLE", "AAPL", "XLI", "XTL", "XLU", "SMH", "XLB", "XLY", "XLP", "XLV", "XLF", "XLU", "IYR", "MSFT", "AMZN", "NVDA", "GOOGL", "BRK-B", "GOOG", "META", "XOM", "UNH","JNJ","JPM", "V", "PG", "MA", "CVX", "HD", "ABBV", "LLY"]
data = yf.download(stock, start="2000-01-01", end="2022-12-31")
# Out:
# [*********************100%***********************]  32 of 32 completed

# %%
data.head(20)
# Out:
#            Adj Close                                                          \
#                 AAPL ABBV      AMZN      BRK-B BTC-USD        CVX GOOG GOOGL
# Date
# 2000-01-03  0.850643  NaN  4.468750  35.299999     NaN  17.849825  NaN   NaN
# 2000-01-04  0.778925  NaN  4.096875  34.080002     NaN  17.849825  NaN   NaN
# 2000-01-05  0.790324  NaN  3.487500  34.639999     NaN  18.170015  NaN   NaN
# 2000-01-06  0.721931  NaN  3.278125  36.080002     NaN  18.943762  NaN   NaN
# 2000-01-07  0.756127  NaN  3.478125  36.400002     NaN  19.277273  NaN   NaN
# 2000-01-10  0.742829  NaN  3.459375  36.259998     NaN  18.756996  NaN   NaN
# 2000-01-11  0.704832  NaN  3.337500  35.580002     NaN  18.583569  NaN   NaN
# 2000-01-12  0.662562  NaN  3.178125  34.900002     NaN  18.516865  NaN   NaN
# 2000-01-13  0.735229  NaN  3.296875  35.200001     NaN  18.690292  NaN   NaN
# 2000-01-14  0.763251  NaN  3.212500  34.020000     NaN  18.570232  NaN   NaN
# ...

# %%
data["Close"].to_csv('Securities.csv', encoding='utf-8')
# ta.to_csv('Technical_Indicators.csv', encoding='utf-8')
